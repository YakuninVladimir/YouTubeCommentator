# %%
from googleapiclient.discovery import build

API_KEY = "AIzaSyAjRPsqPyiOu2RQqr-2Eur7Bp3_oW3WH9U"  

youtube = build("youtube", "v3", developerKey=API_KEY)

def get_youtube_video_description( video_id):
    
    request = youtube.videos().list(
        part="snippet",
        id=video_id
    )
    response = request.execute()
    
    if "items" in response and len(response["items"]) > 0:
        return response["items"][0]["snippet"]["description"]
    else:
        return ""


description = get_youtube_video_description('WYYvHb03Eog')
print(description.split('\n')[0])
# Out:
# The Apple iPhone X is the new super flagship phone from Apple. It comes with an edge-to-edge screen, Face ID — facial recognition system, which can be used to unlock the phone instead of a passcode — and no home button. The iPhone X comes in two colors: space gray and silver. The iPhone X is priced from $999 with 64GB of storage and there’s an upgraded option with 256GB of storage. Preorders open on October 27th, shipping begins November 3rd.

# %%
import pandas as pd
import numpy as np
import json

with open('US_category_id.json', 'r') as file:
    cat_id = json.load(file)

comments = pd.read_csv('UScomments.csv', on_bad_lines='skip', )
comments.columns = ['video_id','comment_text','likes','replies'
]
videos = pd.read_csv('USvideos.csv', on_bad_lines='skip')
# Out:
# C:\Users\Vladimir\AppData\Local\Temp\ipykernel_10768\2739475334.py:8: DtypeWarning: Columns (2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   comments = pd.read_csv('UScomments.csv', on_bad_lines='skip', )

# %%
comments
# Out:
#            video_id                                       comment_text likes  \
# 0       XpVt6Z1Gjjo  I've been following you from the start of your...     3
# 1       XpVt6Z1Gjjo                 Say hi to Kong and maverick for me     3
# 2       XpVt6Z1Gjjo                                MY FAN . attendance     3
# 3       XpVt6Z1Gjjo                                         trending 😉     3
# 4       XpVt6Z1Gjjo                            #1 on trending AYYEEEEE     3
# ...             ...                                                ...   ...
# 691394  EoejGgUNmVU                                             Лучшая     1
# 691395  EoejGgUNmVU  qu'est ce que j'aimerais que tu viennes à Roan...     0
# 691396  EoejGgUNmVU                          Ven a mexico! 😍 te amo LP     0
# 691397  EoejGgUNmVU                                    Islığı yeter...     0
# 691398  EoejGgUNmVU  Kocham tą piosenkę😍❤❤❤byłam zakochana po uszy ...     0
#
#        replies
# 0            0
# ...

# %%
videos
# Out:
#          video_id                                              title  \
# 0     XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 1     K4wEI5zhHB0            iPhone X — Introducing iPhone X — Apple
# 2     cLdxuaxaQwc                                        My Response
# 3     WYYvHb03Eog                          Apple iPhone X first look
# 4     sjlHnJvXdQs                                  iPhone X (parody)
# ...           ...                                                ...
# 7987  xlu6i6lT_vk                     How Do MASSIVE Sinkholes Form?
# 7988  qRoVlH1OcI4  Trump slams Clinton for defending NFL anthem p...
# 7989  EoejGgUNmVU  LP - Lost On You (A Night at The McKittrick Ho...
# 7990  MT1CMTI0EVw  Tré Melvin @ #YouTubeBlack FanFest Washington ...
# 7991  AFxLA3RGjnc  First cosmic event seen in gravitational waves...
#
#                     channel_title  category_id  \
# 0                Logan Paul Vlogs           24
# ...

# %%
from tqdm.auto import tqdm

BATCH_SIZE = 32  

descriptions = []

for i in tqdm(range(0, len(videos), BATCH_SIZE)):

    def process_row(row):
        return get_youtube_video_description(row['video_id'])
    descriptions.extend(list(videos[i:i + BATCH_SIZE].apply(process_row, axis=1)))
print(len(descriptions))

# %%
videos['descriptions'] = descriptions
videos.to_csv('videos.csv')

# %%
import pandas as pd
from transformers import pipeline, AutoTokenizer
import torch

MODEL_NAME = "blanchefort/rubert-base-cased-sentiment"  
TOP_COMMENTS_N = 30  

print("Шаг 1/4: Загрузка данных...")
comments['combined_weight'] = comments['likes'] + comments['replies'] * 10

print("Шаг 2/4: Отбор топовых комментариев...")
top_comments = (
    comments.sort_values(['video_id', 'combined_weight'], ascending=[True, False])
    .groupby('video_id')
    .head(TOP_COMMENTS_N)
    .reset_index(drop=True)
)

print("Шаг 3/4: Инициализация модели...")
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
classifier = pipeline(
    "sentiment-analysis",
    model=MODEL_NAME,
    tokenizer=tokenizer,
    device=0 if torch.cuda.is_available() else -1
)

def analyze_sentiment_batch(texts):
    results = classifier(texts, truncation=True, max_length=512, batch_size=BATCH_SIZE)
    return [result['label'] for result in results]

print("Шаг 4/4: Анализ тональности...")
texts = top_comments['comment_text'].astype(str).tolist()
sentiments = []

for i in tqdm(range(0, len(texts), BATCH_SIZE), desc="Обработка"):
    batch = texts[i:i+BATCH_SIZE]
    try:
        sentiments.extend(analyze_sentiment_batch(batch))
    except Exception as e:
        print(f"Ошибка в батче {i//BATCH_SIZE}: {str(e)}")
        sentiments.extend(['NEUTRAL']*len(batch))

top_comments['sentiment'] = sentiments

top_positive = top_comments[top_comments['sentiment'] == 'POSITIVE']
top_negative = top_comments[top_comments['sentiment'] == 'NEGATIVE']

print("Сохранение результатов...")
top_comments.to_csv('top30_comments_with_sentiment.csv', index=False)
top_positive.to_csv('top30_positive_comments.csv', index=False)
top_negative.to_csv('top30_negative_comments.csv', index=False)

print(f"""
Анализ завершен успешно!
Всего обработано видео: {top_comments['video_id'].nunique()}
Топовых комментариев: {len(top_comments)}
Из них:
  - Позитивных: {len(top_positive)}
  - Негативных: {len(top_negative)}
""")
# Out:
# Шаг 1/4: Загрузка данных...
# Шаг 2/4: Отбор топовых комментариев...
# Шаг 3/4: Инициализация модели...
# Device set to use cuda:0
# Шаг 4/4: Анализ тональности...
# Обработка:   0%|          | 0/2036 [00:00<?, ?it/s]
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Сохранение результатов...
#
# Анализ завершен успешно!
# Всего обработано видео: 2266
# Топовых комментариев: 65150
# Из них:
#   - Позитивных: 11817
#   - Негативных: 32885

# %%
top_comments
# Out:
#           video_id                                       comment_text likes  \
# 0      --JinobXWPk  Hey coyote ive been thingking this for so long...     1
# 1      --JinobXWPk  This guy's a modern day Steve Irwin. Surprised...     2
# 2      --JinobXWPk          B I O L O G I C A L  L A N D M I N E S 💯👏     1
# 3      --JinobXWPk              Get stung by a great white shark next     1
# 4      --JinobXWPk                 GO TO THE HOOD & LOOK FOR SPIDERS!     1
# ...            ...                                                ...   ...
# 65145  zyPIdeF4NFI  Wasn’t this the exactly the same kind of chall...     1
# 65146  zyPIdeF4NFI                              Keep up the good work    10
# 65147  zyPIdeF4NFI                    She looks likes she’s not blind     0
# 65148  zyPIdeF4NFI                 Where my Team Super Unicorns at???    20
# 65149  zyPIdeF4NFI                    She looks likes she’s not blind     0
#
#       replies combined_weight sentiment
# ...

# %%
top_positive['comment_text'].to_list()
# Out:
# ['Never know why I click on a video that has a spider even tho I have Arachnophobia 🤔🤔🤔',
#  "I saw this wandering spider in our bathroom seriously I'm not lying.\\n\\n\\nPS I will never go to Costa Rica!!:-)",
#  'Brazilian wandering spider is the deadliest spider on the 🌎',
#  '❤️=^..^= Mew!',
#  'lol, I love cats and I love this channel  <3',
#  'MMMMM FUCK💦  HORNY AF?  OOOOO SHIT FUCK MEE TILL I CUM💦💦💦🔥🔥🔥😰😰 AND JERK OFF ..💦💦💦💦💦💦💦🔥🔥🔥🔥🔥🔥😍😍😘😘😘😍😍😍😍FUCK ME😍😍😍VIEW ME😍HURRY😍😍😍FUCK HARDER😍😍😍😍😍😍😍😍😍FASTERmo',
#  'i love the cats 😻😻😻😻',
#  'I just said goodbye to my senior kitty. The last thing I really wanted to do was bring kittens into the house but I was alerted to 16 kittens desperately needing homes. I took 2 home. I  am nursing an injured leg and need to rest it a lot.  The kittens insist that my face is the best place to lay down and sleep. I realize how bored I woul be without these 2 kittens!  Figaro and Octavia.',
# ...

# %%
top_comments[top_comments['sentiment'] == 'NEUTRAL']
# Out:
#           video_id                                       comment_text likes  \
# 2      --JinobXWPk          B I O L O G I C A L  L A N D M I N E S 💯👏     1
# 3      --JinobXWPk              Get stung by a great white shark next     1
# 4      --JinobXWPk                 GO TO THE HOOD & LOOK FOR SPIDERS!     1
# 8      --JinobXWPk  Would you rather trek through the Costa Rican ...     1
# 9      --JinobXWPk  please go into the danger zone with the alaska...     1
# ...            ...                                                ...   ...
# 65134  zyPIdeF4NFI             A Molly & Safiya collab would be great    23
# 65141  zyPIdeF4NFI     I knew most of these 🙈 I'm addicted to YouTube    24
# 65147  zyPIdeF4NFI                    She looks likes she’s not blind     0
# 65148  zyPIdeF4NFI                 Where my Team Super Unicorns at???    20
# 65149  zyPIdeF4NFI                    She looks likes she’s not blind     0
#
#       replies combined_weight sentiment
# ...

# %%
top_comments = pd.read_csv('top30_comments_with_sentiment.csv')
videos = pd.read_csv('videos.csv')

# %%
videos['descriptions'] = videos['descriptions'].fillna('')

# %%
def truncate_description(desc, max_words=100):
    if pd.isna(desc):
        return ""
    words = str(desc).split()
    if len(words) > max_words:
        return ' '.join(words[:max_words]) + "..."
    return desc

videos['short_description'] = videos['descriptions'].apply(truncate_description)

# %%
enriched_comments = pd.merge(
    top_comments,
    videos[['video_id', 'title', 'channel_title', 'tags', 'short_description']],
    on='video_id',
    how='left'
)


enriched_comments['enriched_text'] = (
    "sentiment " + enriched_comments['sentiment'] + "\n" + 
    "video: " + enriched_comments['title'] + "\n" +
    "channel: " + enriched_comments['channel_title'] + "\n" +
    "fags: " + enriched_comments['tags'].fillna('').str.replace('|', ', ') + "\n" +
    "description: " + enriched_comments['short_description'].fillna('') + "\n" +
    "comment:\n" + enriched_comments['comment_text']
)


enriched_comments.to_csv('final_enriched_comments.csv', index=False)

print(f"Готово! Обогащено {len(enriched_comments)} комментариев")
print("Пример обогащенного текста:")
print(enriched_comments['enriched_text'].iloc[0][:1000] + "...")
# Out:
# Готово! Обогащено 226649 комментариев
# Пример обогащенного текста:
# sentiment NEGATIVE
# video: DANGEROUS Jungle Spider!
# channel: Brave Wilderness
# fags: adventure, adventurous, animals, breaking, breaking trail, coyote, coyote peterson, peterson, snapping turtle, trail, wild, black widow spider, spider, brave, brave wilderness, wildlife, black widow challenge, spider bite, brown recluse, holding a black widow, deadly spider, dangerous spider, scary, golden orb weaver, big creepy spider, spider challenge, giant spider, animal adventure, jungle spider, wandering spider, brazilian wandering spider, banana spider, dangerous jungle spider
# ...

# %%
import pandas as pd
from transformers import GPT2Tokenizer, GPT2LMHeadModel, Trainer, TrainingArguments
from transformers import DataCollatorForLanguageModeling

from datasets import Dataset
import torch


df = pd.read_csv('final_enriched_comments.csv')
texts = df['enriched_text'].tolist()[:10000]


dataset = Dataset.from_dict({'text': texts})


tokenizer = GPT2Tokenizer.from_pretrained("openai-community/gpt2-large")
tokenizer.pad_token = tokenizer.eos_token  


data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False  
)

def tokenize_function(examples):
    return tokenizer(examples["text"], truncation=True, max_length=512, padding="max_length", return_tensors="pt")

tokenized_dataset = dataset.map(tokenize_function, batched=True)
# Out:
# C:\Users\Vladimir\AppData\Local\Temp\ipykernel_5020\1004781817.py:9: DtypeWarning: Columns (2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('final_enriched_comments.csv')
# Map:   0%|          | 0/10000 [00:00<?, ? examples/s]

# %%
from transformers import AutoModelForCausalLM, GPT2LMHeadModel


model = GPT2LMHeadModel.from_pretrained("openai-community/gpt2-large")

for param in model.base_model.parameters():
    param.requires_grad = False  
    
for param in model.transformer.h[-4:].parameters():  
    param.requires_grad = True

# %%
training_args = TrainingArguments(
    output_dir="./gpt2_finetuned_extra",
    overwrite_output_dir=True,
    num_train_epochs=3,
    per_device_train_batch_size=1, 
    save_steps=10_000,
    save_total_limit=2,
    prediction_loss_only=True,
    learning_rate=5e-5,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=100,
    fp16=torch.cuda.is_available(),
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
    data_collator=data_collator,  
)

# %%
print("Начинаем дообучение модели...")
trainer.train()
print("Дообучение завершено!")

# Сохранение модели
model.save_pretrained("./gpt2_finetuned_extra")
tokenizer.save_pretrained("./gpt2_finetuned_extra")
# Out:
# Начинаем дообучение модели...
# `loss_type=None` was set in the config but it is unrecognised.Using the default loss: `ForCausalLMLoss`.
#     <div>
#
#       <progress value='30000' max='30000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [30000/30000 3:45:34, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>2.724900</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>2.349800</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>2.083400</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.802100</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.558900</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.391900</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>1.296600</td>
#     </tr>
# ...

# %%
from transformers import pipeline

generator = pipeline(
    'text-generation',
    model=model,
    tokenizer=tokenizer,
    device=0 if torch.cuda.is_available() else -1
)

sample_prompt = "sentiment: POSITIVE \n video: how to cook cat meat \n channel: dishes of the world \n tags: cat, meat, travel \n description: video about how to coock cat meat \n comment:"
generated = generator(
    sample_prompt,
    max_length=200,
    num_return_sequences=1,
    temperature=0.7,
    top_p=0.9
)

print("\nСгенерированный текст:")
print(generated[0]['generated_text'])
# Out:
# Device set to use cuda:0
# Сгенерированный текст:
# sentiment: POSITIVE
#  video: how to cook cat meat
#  channel: dishes of the world
#  tags: cat, meat, travel
#  description: video about how to coock cat meat
#  comment: How to make cat meat at home. Easy and healthy. Cat is a very smart animal. :)
# Can you please help me out here? :)
# Do you think you know how to make cat meat? :)
# I have a feeling you're going to make a lot of this. :)  To start you off, you can use this recipe. :) cat = chicken, or any other type of meat. I just love chicken. :)
# How to coock cat meat. Easy and healthy. :)
# Here's a video to get you started. :)
# I hope you find this helpful. :) If you have any questions, feel free to ask me! :) <3 <3 <3 <3 <3 <3 <3 <
